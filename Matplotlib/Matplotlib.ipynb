# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Used_Bikes.csv')

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
bajaj = df[df['brand']=="Bajaj"]

# %%
bajaj
# Out:
#                       bike_name     price       city  kms_driven  \
# 12           Bajaj Pulsar NS200   78000.0  Bangalore      9900.0
# 13          Bajaj Discover 100M   29499.0      Delhi     20000.0
# 14          Bajaj Discover 125M   29900.0      Delhi     20000.0
# 15       Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0
# 16       Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0
# ...                         ...       ...        ...         ...
# 32632  Bajaj Avenger Street 220   55005.0    Godhara      6600.0
# 32637        Bajaj Pulsar 150cc   25000.0      Delhi     32588.0
# 32641       Bajaj Avenger 220cc   41000.0      Delhi     20245.0
# 32645  Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32647        Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#               owner   age  power  brand
# 12      First Owner   4.0  200.0  Bajaj
# 13      First Owner   8.0  100.0  Bajaj
# 14      First Owner   7.0  125.0  Bajaj
# ...

# %%
bajaj.duplicated().sum()
# Out:
# 9132

# %%
plt.plot(bajaj['price'])

# %%
population_India = [100,300,430,480,540,580]
population_China = [100,120,300,330,450,490]
population_Usa   = [100,106,115,125,135,150]

year = [15,16,17,18,19,20]

# %%
plt.title('Total_Population')
plt.xlabel('year')
plt.ylabel('population')
plt.plot(year,population_India,marker="*",color='r',label='India',ls="dashed",lw=3)
plt.plot(year,population_China,marker="*",color='y',label='China',ls="dotted",lw=3)
plt.plot(year,population_Usa,marker="*",color='b',label='Usa',lw=3)
plt.legend()
plt.show()

# %%
# scatter plot
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# numericl
plt.scatter(df['age'],df['price'])

# %%
df['age'].max()
# Out:
# 63.0

# %%
# outlairs = completely different from other

# %%
plt.scatter(df['kms_driven'],df['price'])

# %%
plt.scatter(df['price'],df['power'],color='r',marker='*')
plt.title("power vs price")
plt.xlabel("price")
plt.ylabel("power")
plt.show()

# %%
# bar plot
ownership = list(df['owner'].value_counts().keys())
no_of_count = list(df['owner'].value_counts().values)

# %%
plt.bar(ownership,no_of_count,color='r',ec='black')
plt.xticks(rotation=60)
plt.show()

# %%
brands = list(df['brand'].value_counts().keys())
brands
# Out:
# ['Bajaj',
#  'Hero',
#  'Royal Enfield',
#  'Yamaha',
#  'Honda',
#  'Suzuki',
#  'TVS',
#  'KTM',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Benelli',
#  'Mahindra',
#  'Triumph',
#  'Ducati',
#  'BMW',
#  'Jawa',
#  'MV',
#  'Indian',
#  'Ideal',
#  'Rajdoot',
#  'LML',
#  'Yezdi']

# %%
no_of_count = list(df['brand'].value_counts().values)
no_of_count
# Out:
# [11213,
#  6368,
#  4178,
#  3916,
#  2108,
#  1464,
#  1247,
#  1077,
#  737,
#  79,
#  64,
#  56,
#  55,
#  26,
#  22,
#  16,
#  10,
#  4,
#  3,
#  2,
#  1,
#  1,
#  1]

# %%
plt.bar(brands,no_of_count,color='r',ec='k')
plt.xlabel("brands")
plt.ylabel("no_of_counts")
plt.xticks(rotation=60)
plt.show()

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
owners = list(df['owner'].value_counts().keys())
no_of_count = list(df['owner'].value_counts().values)

# %%
owners
# Out:
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']

# %%
no_of_count
# Out:
# [29964, 2564, 108, 12]

# %%
plt.bar(owners,no_of_count,color='r',ec='k')
plt.title('ownership')
plt.xlabel('owners')
plt.ylabel('no_of_count')
plt.xticks(rotation=60)
plt.show()

# %%
# histogram

# %%
age = np.random.randint(5,110,550)

# %%
age
# Out:
# array([ 64,  73,  39,   9,   6,   5,  75,  97,  35,  49,  77,  46,  99,
#         51,  55, 100,  14,  77, 102, 104,  30,   8,  79,  41,  36,  85,
#         91,  96,  31,  69,  16,  67,  58,  59,  17,  57,  89,  61,  11,
#         31,  66,  48,  55, 104,  79,  78,  78,  51,  96,  76,  85,  12,
#         85,  83,  99,  37, 102,  62,  97,  46,  59,  51,  16,  21,  55,
#         70,   8,  53,  87,  59,  48,   6,  84,  48,  52,  38,  35,  12,
#         10, 104,   5,  86,  89,  88,  77,  48,  99,  83,  57,  80,  14,
#         24,  56,  88,  93,   5,  26,  83, 103,  22,  51,  20,  34,   7,
#         89,  38,  55,  69, 109,   5, 100, 103, 109,  60,  38,   9,  56,
#         19,  81,  42,  61,  68,  16, 105,  65,  66,  79,  84,   8,  87,
#        102,  88,  24,  44,  69,  89,  73,  79,  28,  32,  56,  27,  46,
#         88,  12,  95, 100,  27,  60,  79,  94,   8,  24,  40,  61,  45,
#         10,  79,  11,  95,  72,  58,  47,  75,  76,  11,  70,  91,  14,
# ...

# %%
bin = [0,18,30,45,60,90,120]

# %%
plt.plot(age)

# %%
plt.hist(age,color='r',ec='k',bins=bin)
plt.show()

# %%
# pie bar

# %%
population = ['India','China','Pakistan','Russia']
population_count = [2500,2800,3500,4200]
ls=[0,0,0,0.4]

# %%
plt.pie(population_count,labels=population,explode=ls,shadow=True,wedgeprops={'ec':'k'},autopct='%1.2f%%')
plt.show()
