# %%
import numpy as np
import pandas as pd

# %%
dt={'name':['aditya','kumar','sinha'],'branch':['cse','ece','civil'],'roll_no':[120,125,130]}

# %%
dt
# Out:
# {'name': ['aditya', 'kumar', 'sinha'],
#  'branch': ['cse', 'ece', 'civil'],
#  'roll_no': [120, 125, 130]}

# %%
df = pd.DataFrame(dt)

# %%
df
# Out:
#      name branch  roll_no
# 0  aditya    cse      120
# 1   kumar    ece      125
# 2   sinha  civil      130

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# name       object
# branch     object
# roll_no     int64
# dtype: object

# %%
arr=np.random.randint(10,50,20)

# %%
arr
# Out:
# array([24, 44, 13, 36, 15, 16, 37, 12, 28, 21, 28, 48, 23, 46, 14, 11, 33,
#        45, 17, 49])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
ser1 = pd.Series(arr,name='random_number')

# %%
ser2 = pd.Series(arr,name="random_number_2")

# %%
pd.concat([ser1,ser2],axis='columns')
# Out:
#     random_number  random_number_2
# 0              24               24
# 1              44               44
# 2              13               13
# 3              36               36
# 4              15               15
# 5              16               16
# 6              37               37
# 7              12               12
# 8              28               28
# 9              21               21
# 10             28               28
# 11             48               48
# 12             23               23
# 13             46               46
# 14             14               14
# 15             11               11
# 16             33               33
# 17             45               45
# 18             17               17
# 19             49               49

# %%
df = pd.read_csv('Used_Bikes.csv')

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10)
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (32648, 8)

# %%
df.dtypes
# Out:
# bike_name      object
# price         float64
# city           object
# kms_driven    float64
# owner          object
# age           float64
# power         float64
# brand          object
# dtype: object

# %%
# data accession
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['price'].value_counts()
# Out:
# price
# 25000.0     2071
# 35000.0     1446
# 70000.0     1358
# 18000.0     1356
# 32000.0     1350
#             ...
# 73700.0        1
# 104300.0       1
# 115204.0       1
# 386000.0       1
# 61483.0        1
# Name: count, Length: 1232, dtype: int64

# %%
df[['city']]
# Out:
#             city
# 0      Ahmedabad
# 1          Delhi
# 2          Delhi
# 3      Bangalore
# 4      Bangalore
# ...          ...
# 32643      Delhi
# 32644     Karnal
# 32645      Delhi
# 32646     Jaipur
# 32647       Pune
#
# [32648 rows x 1 columns]

# %%
df[['city']].value_counts()
# Out:
# city
# Delhi        7318
# Bangalore    2723
# Mumbai       2591
# Hyderabad    2160
# Pune         1724
#              ...
# Jajpur          1
# Banka           1
# Parola          1
# Pathankot       1
# Zirakpur        1
# Name: count, Length: 443, dtype: int64

# %%
df[['city','age']]
# Out:
#             city   age
# 0      Ahmedabad   3.0
# 1          Delhi   4.0
# 2          Delhi   8.0
# 3      Bangalore   4.0
# 4      Bangalore   3.0
# ...          ...   ...
# 32643      Delhi   4.0
# 32644     Karnal   9.0
# 32645      Delhi   6.0
# 32646     Jaipur  16.0
# 32647       Pune  13.0
#
# [32648 rows x 2 columns]

# %%
df[['city','age','price']]
# Out:
#             city   age     price
# 0      Ahmedabad   3.0   35000.0
# 1          Delhi   4.0  119900.0
# 2          Delhi   8.0  600000.0
# 3      Bangalore   4.0   65000.0
# 4      Bangalore   3.0   80000.0
# ...          ...   ...       ...
# 32643      Delhi   4.0   39000.0
# 32644     Karnal   9.0   30000.0
# 32645      Delhi   6.0   60000.0
# 32646     Jaipur  16.0   15600.0
# 32647       Pune  13.0   22000.0
#
# [32648 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['bike_name', 'price', 'city', 'kms_driven', 'owner', 'age', 'power',
#        'brand'],
#       dtype='object')

# %%
df[['city','age','price']].head(10)
# Out:
#         city  age     price
# 0  Ahmedabad  3.0   35000.0
# 1      Delhi  4.0  119900.0
# 2      Delhi  8.0  600000.0
# 3  Bangalore  4.0   65000.0
# 4  Bangalore  3.0   80000.0
# 5      Delhi  6.0   53499.0
# 6      Delhi  3.0   85000.0
# 7      Delhi  3.0   45000.0
# 8  Bangalore  3.0  145000.0
# 9      Delhi  7.0   88000.0

# %%
# loc and iloc : used to fetch data from row and column
df.loc[5].head(5)
# Out:
# bike_name     Yamaha FZs 150cc
# price                  53499.0
# city                     Delhi
# kms_driven             25000.0
# owner              First Owner
# Name: 5, dtype: object

# %%
df.loc[0:10,['bike_name','price','city']]
# Out:
#                                    bike_name     price       city
# 0         TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad
# 1                Royal Enfield Classic 350cc  119900.0      Delhi
# 2                       Triumph Daytona 675R  600000.0      Delhi
# 3                       TVS Apache RTR 180cc   65000.0  Bangalore
# 4       Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
# 5                           Yamaha FZs 150cc   53499.0      Delhi
# 6              Honda CB Hornet 160R  ABS DLX   85000.0      Delhi
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi
# 10                  Yamaha YZF-R15 2.0 150cc   72000.0  Bangalore

# %%
df.iloc[0:10,0:3]
# Out:
#                                   bike_name     price       city
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad
# 1               Royal Enfield Classic 350cc  119900.0      Delhi
# 2                      Triumph Daytona 675R  600000.0      Delhi
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
# 5                          Yamaha FZs 150cc   53499.0      Delhi
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi

# %%
# royal_enfield = df[df['brand']==Royal Enfield]
royal_enfield = df[df['brand'] == "Royal Enfield"]
royal_enfield.head(10)
# Out:
#                                    bike_name     price        city  \
# 1                Royal Enfield Classic 350cc  119900.0       Delhi
# 8          Royal Enfield Thunderbird X 350cc  145000.0   Bangalore
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0       Delhi
# 23        Royal Enfield Classic Chrome 500cc  121700.0      Kalyan
# 36               Royal Enfield Classic 350cc   98800.0       Kochi
# 38         Royal Enfield Thunderbird X 500cc  190500.0  Samastipur
# 40           Royal Enfield Thunderbird 350cc   70000.0      Nadiad
# 42        Royal Enfield Bullet Electra 350cc   78000.0     Lucknow
# 44               Royal Enfield Classic 350cc   85000.0       Delhi
# 46           Royal Enfield Thunderbird 350cc   55346.0       Noida
#
#     kms_driven         owner   age  power          brand
# 1      11000.0   First Owner   4.0  350.0  Royal Enfield
# 8       9190.0   First Owner   3.0  350.0  Royal Enfield
# 9      19000.0  Second Owner   7.0  500.0  Royal Enfield
# ...

# %%
royal_enfield.shape
# Out:
# (4178, 8)

# %%
royal_enfield = df[(df['brand']== "Royal Enfield")&(df['city']=="Delhi")&(df['price']<=10000)]

# %%
royal_enfield
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
df.columns = ['bike_name', 'price', 'city', 'kms_driven', 'ownership', 'bike_age', 'bike_power',
       'brand']

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#       ownership  bike_age  bike_power          brand
# 0   First Owner       3.0       110.0            TVS
# ...

# %%
Delhi = df[df['city']=="Delhi"]

# %%
Delhi.head(10)
# Out:
#                                    bike_name     price   city  kms_driven  \
# 1                Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 2                       Triumph Daytona 675R  600000.0  Delhi       110.0
# 5                           Yamaha FZs 150cc   53499.0  Delhi     25000.0
# 6              Honda CB Hornet 160R  ABS DLX   85000.0  Delhi      8200.0
# 7        Hero Splendor Plus Self Alloy 100cc   45000.0  Delhi     12645.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0  Delhi     19000.0
# 13                       Bajaj Discover 100M   29499.0  Delhi     20000.0
# 14                       Bajaj Discover 125M   29900.0  Delhi     20000.0
# 19                       Bajaj Discover 125M   29900.0  Delhi     20000.0
# 22       Hero Splendor iSmart Plus IBS 110cc   46500.0  Delhi      3500.0
#
#        ownership  bike_age  bike_power          brand
# 1    First Owner       4.0       350.0  Royal Enfield
# ...

# %%
df['ownership'].value_counts()
# Out:
# ownership
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
df[df['ownership']=='First Owner']
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# add or delete column

# %%
df.drop(['price','city'],axis='columns')
# Out:
#                                   bike_name  kms_driven    ownership  \
# 0        TVS Star City Plus Dual Tone 110cc     17654.0  First Owner
# 1               Royal Enfield Classic 350cc     11000.0  First Owner
# 2                      Triumph Daytona 675R       110.0  First Owner
# 3                      TVS Apache RTR 180cc     16329.0  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition     10000.0  First Owner
# ...                                     ...         ...          ...
# 32643                Hero Passion Pro 100cc     22000.0  First Owner
# 32644                  TVS Apache RTR 180cc      6639.0  First Owner
# 32645              Bajaj Avenger Street 220     20373.0  First Owner
# 32646             Hero Super Splendor 125cc     84186.0  First Owner
# 32647                    Bajaj Pulsar 150cc     60857.0  First Owner
#
#        bike_age  bike_power          brand
# 0           3.0       110.0            TVS
# 1           4.0       350.0  Royal Enfield
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#      ownership  bike_age  bike_power          brand
# 0  First Owner       3.0       110.0            TVS
# 1  First Owner       4.0       350.0  Royal Enfield
# 2  First Owner       8.0       675.0        Triumph
# 3  First Owner       4.0       180.0            TVS
# 4  First Owner       3.0       150.0         Yamaha

# %%
df['price_inc_5k']=df['price']+5000

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['bike_age_inc_5y'] = df['bike_age']+5

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df = df.drop(['price_inc_5k','bike_age_inc_5y'],axis='columns')

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
ls = []
for price in df['price']:
    if(price<=50000):
        ls.append('middle class')
    elif(price>50000 and price<100000):
        ls.append('high class bike')
    elif(price>100000):
        ls.append('super bike')
    else:
        ls.append('i dont know')

# %%
df['bike_class']=ls

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#       ownership  bike_age  bike_power          brand       bike_class
# ...

# %%
df['ownership']
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4        First Owner
#             ...
# 32643    First Owner
# 32644    First Owner
# 32645    First Owner
# 32646    First Owner
# 32647    First Owner
# Name: ownership, Length: 32648, dtype: object

# %%
df['ownership'].value_counts()
# Out:
# ownership
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
list(df['ownership'].value_counts().keys())
# Out:
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']

# %%
list(df['ownership'].value_counts().values)
# Out:
# [29964, 2564, 108, 12]

# %%
df['ownership'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth Owner Or More'], dtype=object)

# %%
df['ownership'].nunique()
# Out:
# 4

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
cat_col=df.select_dtypes(include="O")

# %%
cat_col
# Out:
#                                   bike_name       city    ownership  \
# 0        TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner
# 1               Royal Enfield Classic 350cc      Delhi  First Owner
# 2                      Triumph Daytona 675R      Delhi  First Owner
# 3                      TVS Apache RTR 180cc  Bangalore  First Owner
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner
# ...                                     ...        ...          ...
# 32643                Hero Passion Pro 100cc      Delhi  First Owner
# 32644                  TVS Apache RTR 180cc     Karnal  First Owner
# 32645              Bajaj Avenger Street 220      Delhi  First Owner
# 32646             Hero Super Splendor 125cc     Jaipur  First Owner
# 32647                    Bajaj Pulsar 150cc       Pune  First Owner
#
#                brand       bike_class
# 0                TVS     middle class
# 1      Royal Enfield       super bike
# ...

# %%
cat_col.dtypes
# Out:
# bike_name     object
# city          object
# ownership     object
# brand         object
# bike_class    object
# dtype: object

# %%
# numerical

# %%
num_col = df.select_dtypes(exclude="O")

# %%
num_col
# Out:
#           price  kms_driven  bike_age  bike_power
# 0       35000.0     17654.0       3.0       110.0
# 1      119900.0     11000.0       4.0       350.0
# 2      600000.0       110.0       8.0       675.0
# 3       65000.0     16329.0       4.0       180.0
# 4       80000.0     10000.0       3.0       150.0
# ...         ...         ...       ...         ...
# 32643   39000.0     22000.0       4.0       100.0
# 32644   30000.0      6639.0       9.0       180.0
# 32645   60000.0     20373.0       6.0       220.0
# 32646   15600.0     84186.0      16.0       125.0
# 32647   22000.0     60857.0      13.0       150.0
#
# [32648 rows x 4 columns]

# %%
num_col['price']
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
num_col['price'].astype(int)
# Out:
# 0         35000
# 1        119900
# 2        600000
# 3         65000
# 4         80000
#           ...
# 32643     39000
# 32644     30000
# 32645     60000
# 32646     15600
# 32647     22000
# Name: price, Length: 32648, dtype: int32

# %%
num_col['price'].astype(float)
# Out:
# 0         35000.0
# 1        119900.0
# 2        600000.0
# 3         65000.0
# 4         80000.0
#            ...
# 32643     39000.0
# 32644     30000.0
# 32645     60000.0
# 32646     15600.0
# 32647     22000.0
# Name: price, Length: 32648, dtype: float64

# %%
df['price'].mean()
# Out:
# 68295.41763660868
