# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('Used_Bikes.csv')

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
tvs = df[df['brand']=='TVS']

# %%
tvs.head()
# Out:
#                               bike_name    price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                  TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                 TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114          TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130              TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
#
#            owner  age  power brand
# 0    First Owner  3.0  110.0   TVS
# 3    First Owner  4.0  180.0   TVS
# 52   First Owner  5.0  160.0   TVS
# 114  First Owner  3.0  160.0   TVS
# 130  First Owner  5.0  125.0   TVS

# %%
tvs['price'].min()
# Out:
# 5800.0

# %%
bajaj = df[df['brand']=='Bajaj']

# %%
bajaj
# Out:
#                       bike_name     price       city  kms_driven  \
# 12           Bajaj Pulsar NS200   78000.0  Bangalore      9900.0
# 13          Bajaj Discover 100M   29499.0      Delhi     20000.0
# 14          Bajaj Discover 125M   29900.0      Delhi     20000.0
# 15       Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0
# 16       Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0
# ...                         ...       ...        ...         ...
# 32632  Bajaj Avenger Street 220   55005.0    Godhara      6600.0
# 32637        Bajaj Pulsar 150cc   25000.0      Delhi     32588.0
# 32641       Bajaj Avenger 220cc   41000.0      Delhi     20245.0
# 32645  Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32647        Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#               owner   age  power  brand
# 12      First Owner   4.0  200.0  Bajaj
# 13      First Owner   8.0  100.0  Bajaj
# 14      First Owner   7.0  125.0  Bajaj
# ...

# %%
bajaj.head()
# Out:
#                  bike_name     price       city  kms_driven        owner  age  \
# 12      Bajaj Pulsar NS200   78000.0  Bangalore      9900.0  First Owner  4.0
# 13     Bajaj Discover 100M   29499.0      Delhi     20000.0  First Owner  8.0
# 14     Bajaj Discover 125M   29900.0      Delhi     20000.0  First Owner  7.0
# 15  Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0  First Owner  3.0
# 16  Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0  First Owner  3.0
#
#     power  brand
# 12  200.0  Bajaj
# 13  100.0  Bajaj
# 14  125.0  Bajaj
# 15  200.0  Bajaj
# 16  200.0  Bajaj

# %%
bajaj['price'].min()
# Out:
# 6400.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
brand_ground = df.groupby('brand')

# %%
brand_ground

# %%
brand_ground.get_group('Bajaj')
# Out:
#                       bike_name     price       city  kms_driven  \
# 12           Bajaj Pulsar NS200   78000.0  Bangalore      9900.0
# 13          Bajaj Discover 100M   29499.0      Delhi     20000.0
# 14          Bajaj Discover 125M   29900.0      Delhi     20000.0
# 15       Bajaj Pulsar NS200 ABS   90000.0  Bangalore     11574.0
# 16       Bajaj Pulsar RS200 ABS  120000.0  Bangalore     23000.0
# ...                         ...       ...        ...         ...
# 32632  Bajaj Avenger Street 220   55005.0    Godhara      6600.0
# 32637        Bajaj Pulsar 150cc   25000.0      Delhi     32588.0
# 32641       Bajaj Avenger 220cc   41000.0      Delhi     20245.0
# 32645  Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32647        Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
#               owner   age  power  brand
# 12      First Owner   4.0  200.0  Bajaj
# 13      First Owner   8.0  100.0  Bajaj
# 14      First Owner   7.0  125.0  Bajaj
# ...

# %%
brand_ground.get_group('TVS')
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
brand_ground.get_group('Bajaj')['price'].min()
# Out:
# 6400.0

# %%
brand_ground.get_group('TVS')['price'].min()
# Out:
# 5800.0

# %%
brand_ground.get_group('Bajaj')['price'].max()
# Out:
# 195000.0

# %%
brand_ground.get_group('TVS')['price'].max()
# Out:
# 224000.0

# %%
brand_ground[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
brand_ground[['price']].min()
# Out:
#                     price
# brand
# BMW              255000.0
# Bajaj              6400.0
# Benelli          110700.0
# Ducati           380000.0
# Harley-Davidson  250000.0
# Hero               5000.0
# Honda             10000.0
# Hyosung          120000.0
# Ideal            100000.0
# Indian           700000.0
# Jawa             146000.0
# KTM               55000.0
# Kawasaki         110000.0
# LML                4400.0
# MV               950000.0
# Mahindra          17800.0
# Rajdoot           75000.0
# Royal Enfield     33500.0
# Suzuki             8000.0
# TVS                5800.0
# Triumph          500000.0
# Yamaha             9400.0
# Yezdi             68000.0

# %%
brand_ground[['price']].mean()
# Out:
#                         price
# brand
# BMW              5.987500e+05
# Bajaj            4.833127e+04
# Benelli          2.942000e+05
# Ducati           9.355455e+05
# Harley-Davidson  4.529988e+05
# Hero             2.382945e+04
# Honda            5.923047e+04
# Hyosung          2.491678e+05
# Ideal            1.000000e+05
# Indian           1.100000e+06
# Jawa             1.855000e+05
# KTM              1.746697e+05
# Kawasaki         4.116246e+05
# LML              4.400000e+03
# MV               1.325000e+06
# Mahindra         7.250709e+04
# Rajdoot          7.500000e+04
# Royal Enfield    9.856207e+04
# Suzuki           4.594683e+04
# TVS              4.429915e+04
# Triumph          8.274230e+05
# Yamaha           5.706896e+04
# Yezdi            6.800000e+04

# %%
bmw = df[df['brand']=='BMW'].reset_index()
bmw
# Out:
#     index          bike_name      price       city  kms_driven        owner  \
# 0     359        BMW G 310 R   255000.0     Mohali      2200.0  First Owner
# 1     379        BMW G 310 R   255000.0     Mohali      2200.0  First Owner
# 2     567        BMW G 310 R   260000.0     Mumbai      8500.0  First Owner
# 3    1157        BMW G 310 R   270000.0       Pune     12872.0  First Owner
# 4    1206        BMW G 310 R   270000.0       Pune     12872.0  First Owner
# 5    2612       BMW G 310 GS   350000.0     Mumbai     14482.0  First Owner
# 6    2956        BMW G 310 R   360000.0  Bangalore      7093.0  First Owner
# 7    3016  BMW S 1000 XR Pro  1500000.0      Delhi     18000.0  First Owner
# 8    3353        BMW G 310 R   360000.0  Bangalore      7093.0  First Owner
# 9    3831       BMW G 310 GS   350000.0     Mumbai     14482.0  First Owner
# 10   4864  BMW S 1000 RR Pro  1800000.0      Delhi      2600.0  First Owner
# ...

# %%
group_by = df.groupby('owner')
group_by

# %%
group_by[['owner']].min()
# Out:
#                                      owner
# owner
# First Owner                    First Owner
# Fourth Owner Or More  Fourth Owner Or More
# Second Owner                  Second Owner
# Third Owner                    Third Owner

# %%
group_by[['owner']].max()
# Out:
#                                      owner
# owner
# First Owner                    First Owner
# Fourth Owner Or More  Fourth Owner Or More
# Second Owner                  Second Owner
# Third Owner                    Third Owner

# %%
group_by[['price']].agg(['min','max','mean'])
# Out:
#                         price
#                           min        max          mean
# owner
# First Owner            4400.0  1900000.0  69512.420037
# Fourth Owner Or More  11000.0   141000.0  61332.500000
# Second Owner           7500.0  1550000.0  53552.263651
# Third Owner            7000.0   699000.0  81431.916667

# %%
first_owner = df[df['owner']=='First Owner']#.min()
first_owner['price'].min()
# Out:
# 4400.0

# %%
first_owner = df[df['owner']=='First Owner']#.min()
first_owner['price'].max()
# Out:
# 1900000.0

# %%
dt = {
    'NAME':['Aditya','Rishu','Satyam','prince'],
    'BRANCH':['CSE','AIML','DS','CYBER'],
}
dt
# Out:
# {'NAME': ['Aditya', 'Rishu', 'Satyam', 'prince'],
#  'BRANCH': ['CSE', 'AIML', 'DS', 'CYBER']}

# %%
temp = pd.DataFrame(dt)

# %%
temp
# Out:
#      NAME BRANCH
# 0  Aditya    CSE
# 1   Rishu   AIML
# 2  Satyam     DS
# 3  prince  CYBER

# %%
temp.to_csv('hello.csv',index=False)

# %%
temp.isnull().sum()
# Out:
# NAME      0
# BRANCH    0
# dtype: int64

# %%
temp.dropna()#.reset_index() #by default delete row in which null value is pesent
# Out:
#      NAME BRANCH
# 0  Aditya    CSE
# 1   Rishu   AIML
# 2  Satyam     DS
# 3  prince  CYBER

# %%
temp.dropna(axis=1)
# Out:
#      NAME BRANCH
# 0  Aditya    CSE
# 1   Rishu   AIML
# 2  Satyam     DS
# 3  prince  CYBER

# %%
df.loc[20:45,['price']]
# Out:
#        price
# 20  120000.0
# 21   48000.0
# 22   46500.0
# 23  121700.0
# 24   45000.0
# 25   78000.0
# 26   20000.0
# 27   20800.0
# 28   50000.0
# 29   81200.0
# 30   88000.0
# 31   80000.0
# 32   40900.0
# 33  180000.0
# 34   40000.0
# 35   70000.0
# 36   98800.0
# 37   65000.0
# 38  190500.0
# 39  179000.0
# 40   70000.0
# 41   45000.0
# 42   78000.0
# 43  110000.0
# 44   85000.0
# 45   38000.0

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['price'].fillna(111)[20:45]
# Out:
# 20    120000.0
# 21     48000.0
# 22     46500.0
# 23    121700.0
# 24     45000.0
# 25     78000.0
# 26     20000.0
# 27     20800.0
# 28     50000.0
# 29     81200.0
# 30     88000.0
# 31     80000.0
# 32     40900.0
# 33    180000.0
# 34     40000.0
# 35     70000.0
# 36     98800.0
# 37     65000.0
# 38    190500.0
# 39    179000.0
# 40     70000.0
# 41     45000.0
# 42     78000.0
# 43    110000.0
# 44     85000.0
# Name: price, dtype: float64

# %%
df['price'].mean()
# Out:
# 68295.41763660868

# %%
df['price'].fillna(df['price'].mean())[20:45]
# Out:
# 20    120000.0
# 21     48000.0
# 22     46500.0
# 23    121700.0
# 24     45000.0
# 25     78000.0
# 26     20000.0
# 27     20800.0
# 28     50000.0
# 29     81200.0
# 30     88000.0
# 31     80000.0
# 32     40900.0
# 33    180000.0
# 34     40000.0
# 35     70000.0
# 36     98800.0
# 37     65000.0
# 38    190500.0
# 39    179000.0
# 40     70000.0
# 41     45000.0
# 42     78000.0
# 43    110000.0
# 44     85000.0
# Name: price, dtype: float64
