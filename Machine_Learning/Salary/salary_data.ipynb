# %%
import pandas as pd

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.shape
# Out:
# (30, 2)

# %%
# divide data into independent and dependent variable
x= df.drop('Salary',axis=1)

# %%
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y = df[['Salary']]

# %%
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#     YearsExperience
# 29             10.5
# 10              3.9
# 0               1.1
# 11              4.0
# 5               2.9
# 26              9.5
# 4               2.2
# 27              9.6
# 23              8.2
# 22              7.9
# 25              9.0
# 6               3.0
# 17              5.3
# 12              4.0
# 28             10.3
# 13              4.1
# 7               3.2
# 8               3.2
# 19              6.0
# 18              5.9
# 16              5.1
# 24              8.7
# 9               3.7
# 3               2.0

# %%
x_test
# Out:
#     YearsExperience
# 15              4.9
# 1               1.3
# 20              6.8
# 14              4.5
# 21              7.1
# 2               1.5

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train) #model fit
# Out:
# LinearRegression()

# %%
prediction = lr.predict(x_test)

# %%
y_test['prediction_salary']=prediction

# %%
y_test
# Out:
#      Salary  prediction_salary
# 15  67938.0       72014.427434
# 1   46205.0       37906.665034
# 20  91738.0       90015.746479
# 14  61111.0       68224.676056
# 21  98273.0       92858.060012
# 2   37731.0       39801.540723

# %%
df2 = pd.concat([x_test,y_test],axis=1)

# %%
df2
# Out:
#     YearsExperience   Salary  prediction_salary
# 15              4.9  67938.0       72014.427434
# 1               1.3  46205.0       37906.665034
# 20              6.8  91738.0       90015.746479
# 14              4.5  61111.0       68224.676056
# 21              7.1  98273.0       92858.060012
# 2               1.5  37731.0       39801.540723

# %%
lr.score(x_train,y_train) #training score
# Out:
# 0.9581429684429082

# %%
lr.score(x_test,y_test['Salary']) #testing score
# Out:
# 0.9407580592581604
