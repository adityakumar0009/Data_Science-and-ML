# %%
import pandas as pd

# %%
df = pd.read_csv('farmer.csv')

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
labels = df.groupby('label')

# %%
labels[['humidity']].mean()
# Out:
#               humidity
# label
# apple        92.333383
# banana       80.358123
# blackgram    65.118426
# chickpea     16.860439
# coconut      94.844272
# coffee       58.869846
# cotton       79.843474
# grapes       81.875228
# jute         79.639864
# kidneybeans  21.605357
# lentil       64.804785
# maize        65.092249
# mango        50.156573
# mothbeans    53.160418
# mungbean     85.499975
# muskmelon    92.342802
# orange       92.170209
# papaya       92.403388
# pigeonpeas   48.061633
# pomegranate  90.125504
# rice         82.272822
# watermelon   85.160375

# %%
label = list(labels[['N']].mean().index)

# %%
label
# Out:
# ['apple',
#  'banana',
#  'blackgram',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'kidneybeans',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'mungbean',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'pomegranate',
#  'rice',
#  'watermelon']

# %%
nitrogen = list(labels[['N']].mean().values.ravel())
nitrogen
# Out:
# [20.8,
#  100.23,
#  40.02,
#  40.09,
#  21.98,
#  101.2,
#  117.77,
#  23.18,
#  78.4,
#  20.75,
#  18.77,
#  77.76,
#  20.07,
#  21.44,
#  20.99,
#  100.32,
#  19.58,
#  49.88,
#  20.73,
#  18.87,
#  79.89,
#  99.42]

# %%
label = list(labels[['P']].mean().index)
label
# Out:
# ['apple',
#  'banana',
#  'blackgram',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'kidneybeans',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'mungbean',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'pomegranate',
#  'rice',
#  'watermelon']

# %%
label = list(labels[['K']].mean().index)
label
# Out:
# ['apple',
#  'banana',
#  'blackgram',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'kidneybeans',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'mungbean',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'pomegranate',
#  'rice',
#  'watermelon']

# %%
label = labels[['temperature']].mean()
label
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
label = labels[['humidity']].mean()
label
# Out:
#               humidity
# label
# apple        92.333383
# banana       80.358123
# blackgram    65.118426
# chickpea     16.860439
# coconut      94.844272
# coffee       58.869846
# cotton       79.843474
# grapes       81.875228
# jute         79.639864
# kidneybeans  21.605357
# lentil       64.804785
# maize        65.092249
# mango        50.156573
# mothbeans    53.160418
# mungbean     85.499975
# muskmelon    92.342802
# orange       92.170209
# papaya       92.403388
# pigeonpeas   48.061633
# pomegranate  90.125504
# rice         82.272822
# watermelon   85.160375

# %%
label = list(labels[['N']].mean().index)

nitrogen = list(labels[['N']].mean().values.ravel())

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.bar(label,nitrogen,color='blue',ec='black')     
plt.xticks(rotation=90)            
plt.show()

# %%
sns.catplot(x=label,y=nitrogen,kind='bar')
# sns.xticks(rotation=60)
plt.show()

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
x = df.drop('label' ,axis=1)

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
sns.boxplot(x['temperature'])
plt.show()

# %%
sns.boxplot(x['humidity'])
plt.show()

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
plt.subplot(3,3,1)
sns.boxplot(df['N'])
plt.subplot(3,3,1)
sns.boxplot(df['P'])
plt.subplot(3,3,1)
sns.boxplot(df['K'])
plt.subplot(3,3,1)
sns.boxplot(df['temperature'])
plt.subplot(3,3,1)
sns.boxplot(df['humidity'])
plt.subplot(3,3,1)
sns.boxplot(df['ph'])
plt.subplot(3,3,1)
sns.boxplot(df['rainfall'])
plt.show()

# %%
sns.displot(x['temperature'])
plt.show()

# %%
sns.displot(x['K'])
plt.show()

# %%
sns.displot(x['N'])
plt.show()
